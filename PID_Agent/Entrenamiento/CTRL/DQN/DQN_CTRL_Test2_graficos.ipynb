# %% [markdown]
# # W&B Sweep — DQN
# Búsqueda de hiperparámetros para el agente DQN en el ambiente Simple (CSTR).
# - Método: Random Search
# - Proyecto W&B: `Tesis_DQN`
# - Arquitectura: Simple (CTRL únicamente)

# %% [markdown]
# ## 1. Instalación e Imports

# %%
import os
import random
import numpy as np
import torch
import wandb
import sys
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Clonar desde Github:
# !git clone https://github.com/valeriaeskenazi/Control-PID-Adaptativo-Inteligente-mediante-Reinforcement-Learning.git
PROJECT_PATH = '/content/Control-PID-Adaptativo-Inteligente-mediante-Reinforcement-Learning/Version_4'
sys.path.append(PROJECT_PATH)
# Out:
# fatal: destination path 'Control-PID-Adaptativo-Inteligente-mediante-Reinforcement-Learning' already exists and is not an empty directory.

# %%
from Environment.Simulation_Env.Reactor_CSTR import CSTRSimulator
from Environment.PIDControlEnv_simple import PIDControlEnv_Simple
from Agente.DQN.train_DQN import DQNTrainer
from Aux.Plots import SimplePlotter, print_summary

print('Imports completados')
print(f'PyTorch: {torch.__version__}')
print(f'Device: {"CUDA" if torch.cuda.is_available() else "CPU"}')
# Out:
# Imports completados
# PyTorch: 2.10.0+cpu
# Device: CPU

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sat Mar  7 23:26:15 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX PRO 6000 Blac...    Off |   00000000:05:00.0 Off |                    0 |
# | N/A   30C    P0             46W /  600W |       3MiB /  97887MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## 2. Login W&B

# %%
# !pip install wandb --quiet

# %%
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ve326684 (ve326684-universidad-ort-uruguay) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ## 3. Configuración del Sweep

# %%
# ============ CONFIG RUN PRINCIPAL POST-FIX ============

WANDB_ENTITY  = 've326684-universidad-ort-uruguay'
WANDB_PROJECT = 'Tesis_DQN_CTRL'
RUN_NAME      = 'dqn_re_entrnenado_15k'

N_EPISODES               = 15000
EVAL_FREQUENCY           = 100
LOG_FREQUENCY            = 100
SAVE_FREQUENCY           = 2000
EARLY_STOPPING_PATIENCE  = 50
EARLY_STOPPING_MIN_DELTA_PCT = 0.01
SEED                     = 42

trainer_config = {
    'env_config': {
        'architecture'        : 'simple',
        'env_type'            : 'simulation',
        'n_manipulable_vars'  : 2,
        'manipulable_ranges'  : [(300, 420), (90, 115)],
        'manipulable_setpoints': None,
        'dt_usuario'          : 1.0,
        'max_steps'           : 20,
        'max_time_detector'   : 15,
        'reward_dead_band'    : 0.02,
        'delta_percent_ctrl'  : 0.3,
        'reward_weights'      : {'error': 3.0, 'tiempo': 0.1, 'overshoot': 0.1, 'energy': 0.05},
        'pid_limits'          : [(0.01, 5.0), (0.001, 1.0), (0.0001, 1.0)],
        'agent_controller_config': {'agent_type': 'discrete'},
        'env_type_config'     : {'dt': 1.0, 'control_limits': ((300, 420), (90, 115))},
        'stability_config'    : {
            'error_increase_tolerance': 1.2,
            'max_sign_changes_ratio'  : 0.2,
            'max_abrupt_change_ratio' : 0.03,
            'abrupt_change_threshold' : 0.3,
        },
    },
    'agent_ctrl_config': {
        'state_dim'         : 10,
        'action_dim'        : 7,
        'n_vars'            : 2,
        'hidden_dims'       : (128, 64),
        'lr'                : 1e-05,
        'gamma'             : 0.99,
        'epsilon_start'     : 1.0,
        'epsilon_min'       : 0.01,
        'epsilon_decay'     : 0.9995,
        'batch_size'        : 128,
        'target_update_freq': 50,
        'buffer_type'       : 'priority',
        'buffer_size'       : 50000,
        'device'            : 'cuda' if torch.cuda.is_available() else 'cpu',
        'seed'              : SEED,
    },
    'n_episodes'     : N_EPISODES,
    'eval_frequency' : EVAL_FREQUENCY,
    'log_frequency'  : LOG_FREQUENCY,
    'save_frequency' : SAVE_FREQUENCY,
    'checkpoint_dir' : f'checkpoints/{RUN_NAME}',
    'early_stopping_patience'     : EARLY_STOPPING_PATIENCE,
    'early_stopping_min_delta_pct': EARLY_STOPPING_MIN_DELTA_PCT,
    'use_wandb': True,
}

# ============ REPRODUCIBILIDAD ============
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark     = False

# ============ INIT WANDB ============
wandb.init(
    project = WANDB_PROJECT,
    entity  = WANDB_ENTITY,
    name    = RUN_NAME,
    tags    = ['post-fix', 'clamp', '15k', 'produccion'],  # fácil de filtrar en W&B
    config  = trainer_config,
)

# ============ ENTRENAR ============
cstr    = CSTRSimulator(dt=1.0, control_limits=((300, 420), (90, 115)))
trainer = DQNTrainer(trainer_config)
trainer.env.proceso.connect_external_process(cstr)
trainer.train()

# ============ GUARDAR PESOS EN W&B ============
import os
checkpoint_path = f'checkpoints/{RUN_NAME}'
if os.path.exists(checkpoint_path):
    artifact = wandb.Artifact(
        name = f'model_{RUN_NAME}',
        type = 'model',
        description = 'Pesos DQN post-fix clamp, 15k episodios'
    )
    artifact.add_dir(checkpoint_path)
    wandb.log_artifact(artifact)

# ============ MÉTRICAS FINALES ============
wandb.log({
    'final_eval_reward'      : trainer.best_reward,
    'total_episodes'         : len(trainer.episode_rewards),
    'final_epsilon'          : trainer.epsilons[-1] if trainer.epsilons else 0,
    'final_reward_mean10'    : np.mean(trainer.episode_rewards[-10:]),
    'final_energy_mean10'    : np.mean(trainer.episode_energies[-10:]),
    'final_overshoot_mean10' : np.mean(trainer.episode_max_overshoots[-10:]),
})

wandb.finish()
print(f'Run completado: {RUN_NAME}')
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/wandb/run-20260307_232745-vo0ba1tj</code>
# Syncing run <strong><a href='https://wandb.ai/ve326684-universidad-ort-uruguay/Tesis_DQN_CTRL/runs/vo0ba1tj' target="_blank">dqn_re_entrnenado_15k</a></strong> to <a href='https://wandb.ai/ve326684-universidad-ort-uruguay/Tesis_DQN_CTRL' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ve326684-universidad-ort-uruguay/Tesis_DQN_CTRL' target="_blank">https://wandb.ai/ve326684-universidad-ort-uruguay/Tesis_DQN_CTRL</a>
#  View run at <a href='https://wandb.ai/ve326684-universidad-ort-uruguay/Tesis_DQN_CTRL/runs/vo0ba1tj' target="_blank">https://wandb.ai/ve326684-universidad-ort-uruguay/Tesis_DQN_CTRL/runs/vo0ba1tj</a>
# Episodio 0/15000
#   Reward: -2.45
#   Length: 20
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 1.0000
#
# Episodio 100/15000
#   Reward: -0.26
#   Length: 20
#   CTRL Loss: 178.2938
#   CTRL Epsilon: 0.3880
# Evaluación: Reward promedio = -0.54
# Agente guardado en: checkpoints/dqn_re_entrnenado_15k/agent_ctrl_best.pt
# Checkpoint guardado: best
#
# Episodio 200/15000
#   Reward: -1.01
#   Length: 20
#   CTRL Loss: 55.9674
#   CTRL Epsilon: 0.1427
# Evaluación: Reward promedio = -1.36
#   Sin mejora: 1/50
#
# Episodio 300/15000
#   Reward: -0.43
#   Length: 20
#   CTRL Loss: 33.6408
#   CTRL Epsilon: 0.0525
# Evaluación: Reward promedio = -3.08
#   Sin mejora: 2/50
#
# Episodio 400/15000
#   Reward: -0.87
#   Length: 20
#   CTRL Loss: 25.3527
#   CTRL Epsilon: 0.0193
# Evaluación: Reward promedio = -1.21
#   Sin mejora: 3/50
#
# Episodio 500/15000
#   Reward: -0.75
#   Length: 20
#   CTRL Loss: 14.2627
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.63
#   Sin mejora: 4/50
#
# Episodio 600/15000
#   Reward: -0.57
#   Length: 20
#   CTRL Loss: 11.8995
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.53
#   Sin mejora: 5/50
# Agente guardado en: checkpoints/dqn_re_entrnenado_15k/agent_ctrl_best.pt
# Checkpoint guardado: best
#
# Episodio 700/15000
#   Reward: -1.83
#   Length: 20
#   CTRL Loss: 7.5686
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -1.50
#   Sin mejora: 6/50
#
# Episodio 800/15000
#   Reward: -0.44
#   Length: 20
#   CTRL Loss: 5.4487
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.51
#   Sin mejora: 7/50
# Agente guardado en: checkpoints/dqn_re_entrnenado_15k/agent_ctrl_best.pt
# Checkpoint guardado: best
#
# Episodio 900/15000
#   Reward: -1.68
#   Length: 20
#   CTRL Loss: 5.3816
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.94
#   Sin mejora: 8/50
#
# Episodio 1000/15000
#   Reward: -1.97
#   Length: 20
#   CTRL Loss: 4.3353
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -1.89
#   Sin mejora: 9/50
#
# Episodio 1100/15000
#   Reward: -0.73
#   Length: 20
#   CTRL Loss: 4.2022
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.46
# Agente guardado en: checkpoints/dqn_re_entrnenado_15k/agent_ctrl_best.pt
# Checkpoint guardado: best
#
# Episodio 1200/15000
#   Reward: -1.77
#   Length: 20
#   CTRL Loss: 3.3302
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -1.40
#   Sin mejora: 1/50
#
# Episodio 1300/15000
#   Reward: -0.60
#   Length: 20
#   CTRL Loss: 3.1128
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.49
#   Sin mejora: 2/50
#
# Episodio 1400/15000
#   Reward: -0.17
#   Length: 20
#   CTRL Loss: 2.6400
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.61
#   Sin mejora: 3/50
#
# Episodio 1500/15000
#   Reward: -0.55
#   Length: 20
#   CTRL Loss: 2.4910
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.48
#   Sin mejora: 4/50
#
# Episodio 1600/15000
#   Reward: -0.54
#   Length: 20
#   CTRL Loss: 2.5482
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.67
#   Sin mejora: 5/50
#
# Episodio 1700/15000
#   Reward: -0.54
#   Length: 20
#   CTRL Loss: 2.0994
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.69
#   Sin mejora: 6/50
#
# Episodio 1800/15000
#   Reward: -0.47
#   Length: 20
#   CTRL Loss: 1.8365
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.51
#   Sin mejora: 7/50
#
# Episodio 1900/15000
#   Reward: -0.79
#   Length: 20
#   CTRL Loss: 1.6306
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.79
#   Sin mejora: 8/50
#
# Episodio 2000/15000
#   Reward: -2.25
#   Length: 20
#   CTRL Loss: 1.5969
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -1.19
#   Sin mejora: 9/50
# Agente guardado en: checkpoints/dqn_re_entrnenado_15k/agent_ctrl_ep2000.pt
# Checkpoint guardado: ep2000
#
# Episodio 2100/15000
#   Reward: -0.52
#   Length: 20
#   CTRL Loss: 1.6617
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.88
#   Sin mejora: 10/50
#
# Episodio 2200/15000
#   Reward: -1.91
#   Length: 20
#   CTRL Loss: 1.3957
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -1.15
#   Sin mejora: 11/50
#
# Episodio 2300/15000
#   Reward: -0.71
#   Length: 20
#   CTRL Loss: 1.3558
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.70
#   Sin mejora: 12/50
#
# Episodio 2400/15000
#   Reward: -1.80
#   Length: 20
#   CTRL Loss: 1.4309
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.83
#   Sin mejora: 13/50
#
# Episodio 2500/15000
#   Reward: -2.21
#   Length: 20
#   CTRL Loss: 1.2099
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -1.18
#   Sin mejora: 14/50
#
# Episodio 2600/15000
#   Reward: -0.25
#   Length: 20
#   CTRL Loss: 0.8946
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.50
#   Sin mejora: 15/50
#
# Episodio 2700/15000
#   Reward: -0.43
#   Length: 20
#   CTRL Loss: 0.8906
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.41
# Agente guardado en: checkpoints/dqn_re_entrnenado_15k/agent_ctrl_best.pt
# Checkpoint guardado: best
#
# Episodio 2800/15000
#   Reward: -0.67
#   Length: 20
#   CTRL Loss: 0.8298
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.55
#   Sin mejora: 1/50
#
# Episodio 2900/15000
#   Reward: -0.23
#   Length: 20
#   CTRL Loss: 0.8075
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.46
#   Sin mejora: 2/50
#
# Episodio 3000/15000
#   Reward: -0.30
#   Length: 20
#   CTRL Loss: 0.6236
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.64
#   Sin mejora: 3/50
#
# Episodio 3100/15000
#   Reward: -1.64
#   Length: 20
#   CTRL Loss: 0.6736
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.70
#   Sin mejora: 4/50
#
# Episodio 3200/15000
#   Reward: -0.61
#   Length: 20
#   CTRL Loss: 0.6943
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.39
#   Sin mejora: 5/50
# Agente guardado en: checkpoints/dqn_re_entrnenado_15k/agent_ctrl_best.pt
# Checkpoint guardado: best
#
# Episodio 3300/15000
#   Reward: -0.04
#   Length: 20
#   CTRL Loss: 0.6514
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.33
# Agente guardado en: checkpoints/dqn_re_entrnenado_15k/agent_ctrl_best.pt
# Checkpoint guardado: best
#
# Episodio 3400/15000
#   Reward: -0.54
#   Length: 20
#   CTRL Loss: 0.5679
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.43
#   Sin mejora: 1/50
#
# Episodio 3500/15000
#   Reward: -0.64
#   Length: 20
#   CTRL Loss: 0.6389
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.42
#   Sin mejora: 2/50
#
# Episodio 3600/15000
#   Reward: -0.46
#   Length: 20
#   CTRL Loss: 0.5360
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.60
#   Sin mejora: 3/50
#
# Episodio 3700/15000
#   Reward: -0.49
#   Length: 20
#   CTRL Loss: 0.4758
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.65
#   Sin mejora: 4/50
#
# Episodio 3800/15000
#   Reward: -0.39
#   Length: 20
#   CTRL Loss: 0.5258
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.85
#   Sin mejora: 5/50
#
# Episodio 3900/15000
#   Reward: -1.03
#   Length: 20
#   CTRL Loss: 0.5687
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.65
#   Sin mejora: 6/50
#
# Episodio 4000/15000
#   Reward: -0.16
#   Length: 20
#   CTRL Loss: 0.4720
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.85
#   Sin mejora: 7/50
# Agente guardado en: checkpoints/dqn_re_entrnenado_15k/agent_ctrl_ep4000.pt
# Checkpoint guardado: ep4000
#
# Episodio 4100/15000
#   Reward: -0.57
#   Length: 20
#   CTRL Loss: 0.5485
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.57
#   Sin mejora: 8/50
#
# Episodio 4200/15000
#   Reward: -0.51
#   Length: 20
#   CTRL Loss: 0.5440
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.54
#   Sin mejora: 9/50
#
# Episodio 4300/15000
#   Reward: -0.41
#   Length: 20
#   CTRL Loss: 0.4970
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.60
#   Sin mejora: 10/50
#
# Episodio 4400/15000
#   Reward: -0.21
#   Length: 20
#   CTRL Loss: 0.5311
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.41
#   Sin mejora: 11/50
#
# Episodio 4500/15000
#   Reward: -1.62
#   Length: 20
#   CTRL Loss: 0.4995
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -1.33
#   Sin mejora: 12/50
#
# Episodio 4600/15000
#   Reward: -0.63
#   Length: 20
#   CTRL Loss: 0.4497
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.59
#   Sin mejora: 13/50
#
# Episodio 4700/15000
#   Reward: -0.42
#   Length: 20
#   CTRL Loss: 0.4549
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.45
#   Sin mejora: 14/50
#
# Episodio 4800/15000
#   Reward: -0.53
#   Length: 20
#   CTRL Loss: 0.4083
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.70
#   Sin mejora: 15/50
#
# Episodio 4900/15000
#   Reward: -0.39
#   Length: 20
#   CTRL Loss: 0.4869
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.62
#   Sin mejora: 16/50
#
# Episodio 5000/15000
#   Reward: -0.27
#   Length: 20
#   CTRL Loss: 0.3803
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.26
# Agente guardado en: checkpoints/dqn_re_entrnenado_15k/agent_ctrl_best.pt
# Checkpoint guardado: best
#
# Episodio 5100/15000
#   Reward: -0.44
#   Length: 20
#   CTRL Loss: 0.4696
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.75
#   Sin mejora: 1/50
#
# Episodio 5200/15000
#   Reward: -0.34
#   Length: 20
#   CTRL Loss: 0.4275
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.39
#   Sin mejora: 2/50
#
# Episodio 5300/15000
#   Reward: -0.64
#   Length: 20
#   CTRL Loss: 0.3520
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.54
#   Sin mejora: 3/50
#
# Episodio 5400/15000
#   Reward: -0.89
#   Length: 20
#   CTRL Loss: 0.3182
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.36
#   Sin mejora: 4/50
#
# Episodio 5500/15000
#   Reward: -0.12
#   Length: 20
#   CTRL Loss: 0.3191
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.46
#   Sin mejora: 5/50
#
# Episodio 5600/15000
#   Reward: -0.73
#   Length: 20
#   CTRL Loss: 0.3552
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.99
#   Sin mejora: 6/50
#
# Episodio 5700/15000
#   Reward: -0.42
#   Length: 20
#   CTRL Loss: 0.3450
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.47
#   Sin mejora: 7/50
#
# Episodio 5800/15000
#   Reward: -0.23
#   Length: 20
#   CTRL Loss: 0.2768
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.30
#   Sin mejora: 8/50
#
# Episodio 5900/15000
#   Reward: -0.22
#   Length: 20
#   CTRL Loss: 0.2740
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.34
#   Sin mejora: 9/50
#
# Episodio 6000/15000
#   Reward: -0.44
#   Length: 20
#   CTRL Loss: 0.3039
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.40
#   Sin mejora: 10/50
# Agente guardado en: checkpoints/dqn_re_entrnenado_15k/agent_ctrl_ep6000.pt
# Checkpoint guardado: ep6000
#
# Episodio 6100/15000
#   Reward: -0.31
#   Length: 20
#   CTRL Loss: 0.2847
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.50
#   Sin mejora: 11/50
#
# Episodio 6200/15000
#   Reward: -0.45
#   Length: 20
#   CTRL Loss: 0.2555
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.54
#   Sin mejora: 12/50
#
# Episodio 6300/15000
#   Reward: -0.52
#   Length: 20
#   CTRL Loss: 0.2771
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.28
#   Sin mejora: 13/50
#
# Episodio 6400/15000
#   Reward: -0.25
#   Length: 20
#   CTRL Loss: 0.2517
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.42
#   Sin mejora: 14/50
#
# Episodio 6500/15000
#   Reward: -0.76
#   Length: 20
#   CTRL Loss: 0.2202
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.38
#   Sin mejora: 15/50
#
# Episodio 6600/15000
#   Reward: -0.17
#   Length: 20
#   CTRL Loss: 0.1775
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.37
#   Sin mejora: 16/50
#
# Episodio 6700/15000
#   Reward: -0.22
#   Length: 20
#   CTRL Loss: 0.2013
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.45
#   Sin mejora: 17/50
#
# Episodio 6800/15000
#   Reward: -0.18
#   Length: 20
#   CTRL Loss: 0.1891
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.50
#   Sin mejora: 18/50
#
# Episodio 6900/15000
#   Reward: -0.26
#   Length: 20
#   CTRL Loss: 0.1988
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.45
#   Sin mejora: 19/50
#
# Episodio 7000/15000
#   Reward: -0.38
#   Length: 20
#   CTRL Loss: 0.1869
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.51
#   Sin mejora: 20/50
#
# Episodio 7100/15000
#   Reward: -0.85
#   Length: 20
#   CTRL Loss: 0.2137
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.70
#   Sin mejora: 21/50
#
# Episodio 7200/15000
#   Reward: -0.37
#   Length: 20
#   CTRL Loss: 0.2051
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.45
#   Sin mejora: 22/50
#
# Episodio 7300/15000
#   Reward: -0.88
#   Length: 20
#   CTRL Loss: 0.1619
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.63
#   Sin mejora: 23/50
#
# Episodio 7400/15000
#   Reward: -0.48
#   Length: 20
#   CTRL Loss: 0.1366
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.64
#   Sin mejora: 24/50
#
# Episodio 7500/15000
#   Reward: -0.32
#   Length: 20
#   CTRL Loss: 0.1849
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.55
#   Sin mejora: 25/50
#
# Episodio 7600/15000
#   Reward: -0.22
#   Length: 20
#   CTRL Loss: 0.1721
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.36
#   Sin mejora: 26/50
#
# Episodio 7700/15000
#   Reward: -0.54
#   Length: 20
#   CTRL Loss: 0.1673
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.36
#   Sin mejora: 27/50
#
# Episodio 7800/15000
#   Reward: -0.50
#   Length: 20
#   CTRL Loss: 0.1784
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.41
#   Sin mejora: 28/50
#
# Episodio 7900/15000
#   Reward: -0.43
#   Length: 20
#   CTRL Loss: 0.1692
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.44
#   Sin mejora: 29/50
#
# Episodio 8000/15000
#   Reward: -0.37
#   Length: 20
#   CTRL Loss: 0.1676
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.46
#   Sin mejora: 30/50
# Agente guardado en: checkpoints/dqn_re_entrnenado_15k/agent_ctrl_ep8000.pt
# Checkpoint guardado: ep8000
#
# Episodio 8100/15000
#   Reward: -0.38
#   Length: 20
#   CTRL Loss: 0.1579
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.41
#   Sin mejora: 31/50
#
# Episodio 8200/15000
#   Reward: -0.32
#   Length: 20
#   CTRL Loss: 0.1678
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.30
#   Sin mejora: 32/50
#
# Episodio 8300/15000
#   Reward: -0.72
#   Length: 20
#   CTRL Loss: 0.1200
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.44
#   Sin mejora: 33/50
#
# Episodio 8400/15000
#   Reward: -0.30
#   Length: 20
#   CTRL Loss: 0.1245
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.55
#   Sin mejora: 34/50
#
# Episodio 8500/15000
#   Reward: -0.16
#   Length: 20
#   CTRL Loss: 0.1280
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.44
#   Sin mejora: 35/50
#
# Episodio 8600/15000
#   Reward: -0.43
#   Length: 20
#   CTRL Loss: 0.1580
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.42
#   Sin mejora: 36/50
#
# Episodio 8700/15000
#   Reward: -0.44
#   Length: 20
#   CTRL Loss: 0.1481
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.61
#   Sin mejora: 37/50
#
# Episodio 8800/15000
#   Reward: -0.32
#   Length: 20
#   CTRL Loss: 0.1370
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.93
#   Sin mejora: 38/50
#
# Episodio 8900/15000
#   Reward: -0.42
#   Length: 20
#   CTRL Loss: 0.1175
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.50
#   Sin mejora: 39/50
#
# Episodio 9000/15000
#   Reward: -1.43
#   Length: 20
#   CTRL Loss: 0.1037
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.38
#   Sin mejora: 40/50
#
# Episodio 9100/15000
#   Reward: -0.43
#   Length: 20
#   CTRL Loss: 0.1395
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.54
#   Sin mejora: 41/50
#
# Episodio 9200/15000
#   Reward: -0.66
#   Length: 20
#   CTRL Loss: 0.1138
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.50
#   Sin mejora: 42/50
#
# Episodio 9300/15000
#   Reward: -0.34
#   Length: 20
#   CTRL Loss: 0.0971
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.58
#   Sin mejora: 43/50
#
# Episodio 9400/15000
#   Reward: -0.36
#   Length: 20
#   CTRL Loss: 0.1186
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.44
#   Sin mejora: 44/50
#
# Episodio 9500/15000
#   Reward: -0.72
#   Length: 20
#   CTRL Loss: 0.1165
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.38
#   Sin mejora: 45/50
#
# Episodio 9600/15000
#   Reward: -0.40
#   Length: 20
#   CTRL Loss: 0.1586
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.36
#   Sin mejora: 46/50
#
# Episodio 9700/15000
#   Reward: -0.42
#   Length: 20
#   CTRL Loss: 0.1296
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.36
#   Sin mejora: 47/50
#
# Episodio 9800/15000
#   Reward: -0.44
#   Length: 20
#   CTRL Loss: 0.1339
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.90
#   Sin mejora: 48/50
#
# Episodio 9900/15000
#   Reward: -0.27
#   Length: 20
#   CTRL Loss: 0.1540
#   CTRL Epsilon: 0.0100
# Evaluación: Reward promedio = -0.46
#   Sin mejora: 49/50
#
# Episodio 10000/15000
#   Reward: -0.20
#   Length: 20
#   CTRL Loss: 0.1429
#   CTRL Epsilon: 0.0100
# wandb: Adding directory to artifact (checkpoints/dqn_re_entrnenado_15k)... Done. 0.0s
# Evaluación: Reward promedio = -0.44
#   Sin mejora: 50/50
# Early stopping en episodio 10000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>energy</td><td>▁▂█▁▂▅▆▁▂▁▂▁▁▅▂▁▂▆▁▃▂▂▂▂▁▄▁▁▁▃▁▂▁▁▂▁▆▁▂▁</td></tr><tr><td>epsilon</td><td>█▇▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval_reward</td><td>▁▂▆▄▇▇▆▇▅▄▆▅▆▆█▆▄▆▄▇▇▆▇▅█▄█▇██▆▇▇▆▇▇▇██▇</td></tr><tr><td>final_energy_mean10</td><td>▁</td></tr><tr><td>final_epsilon</td><td>▁</td></tr><tr><td>final_eval_reward</td><td>▁</td></tr><tr><td>final_overshoot_mean10</td><td>▁</td></tr><tr><td>final_reward_mean10</td><td>▁</td></tr><tr><td>kd_var0</td><td>▃▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁█</td></tr><tr><td>kd_var1</td><td>▁▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁</td></tr><tr><td>+8</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>energy</td><td>1337135.02357</td></tr><tr><td>epsilon</td><td>0.01</td></tr><tr><td>eval_reward</td><td>-0.43999</td></tr><tr><td>final_energy_mean10</td><td>1284918.79764</td></tr><tr><td>final_epsilon</td><td>0.01</td></tr><tr><td>final_eval_reward</td><td>-0.26421</td></tr><tr><td>final_overshoot_mean10</td><td>9.1926</td></tr><tr><td>final_reward_mean10</td><td>-0.65165</td></tr><tr><td>kd_var0</td><td>0.00014</td></tr><tr><td>kd_var1</td><td>0.0001</td></tr><tr><td>+8</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dqn_re_entrnenado_15k</strong> at: <a href='https://wandb.ai/ve326684-universidad-ort-uruguay/Tesis_DQN_CTRL/runs/vo0ba1tj' target="_blank">https://wandb.ai/ve326684-universidad-ort-uruguay/Tesis_DQN_CTRL/runs/vo0ba1tj</a><br> View project at: <a href='https://wandb.ai/ve326684-universidad-ort-uruguay/Tesis_DQN_CTRL' target="_blank">https://wandb.ai/ve326684-universidad-ort-uruguay/Tesis_DQN_CTRL</a><br>Synced 5 W&B file(s), 0 media file(s), 6 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260307_232745-vo0ba1tj/logs</code>
# Run completado: dqn_re_entrnenado_15k

# %% [markdown]
# Analisis de resultados

# %%
api = wandb.Api()
r = api.run('ve326684-universidad-ort-uruguay/Tesis_DQN_CTRL/vo0ba1tj')
hist = list(r.scan_history())
df_post = pd.DataFrame(hist)
print(df_post.columns.tolist())
# Out:
# ['epsilon', '_timestamp', 'kp_var0', '_step', 'kd_var1', 'ki_var0', 'overshoot', 'reward', 'energy', 'kd_var0', 'ki_var1', 'loss', '_runtime', 'kp_var1', 'eval_reward', 'final_energy_mean10', 'final_overshoot_mean10', 'final_reward_mean10', 'final_eval_reward', 'total_episodes', 'final_epsilon']

# %%
fig, axes = plt.subplots(2, 3, figsize=(16, 8))
metricas = ['reward', 'eval_reward', 'loss', 'overshoot', 'kp_var0', 'kp_var1']

for ax, col in zip(axes.flat, metricas):
    d = df_post[['_step', col]].dropna()
    ax.plot(d['_step'], d[col], alpha=0.3, color='steelblue')
    ax.plot(d['_step'], d[col].rolling(200, min_periods=1).mean(), color='red', lw=2)
    ax.set_title(col)
    ax.set_xlabel('Episodio')

plt.suptitle('dqn_postfix_15k — post clamp fix', fontweight='bold')
plt.tight_layout()
plt.show()

# %%
from Agente.DQN.algorithm_DQN import DQNAgent
from Aux.PIDComponents_PID import PIDController
from Aux.PIDComponents_time import ResponseTimeDetector
from Aux.PIDComponentes_translate import ApplyAction

# %%
agent = DQNAgent(
    state_dim=10,
    action_dim=7,
    n_vars=2,
    agent_role='ctrl',
    hidden_dims=(128, 64),
    device='cpu',
    seed=42
)
agent.load('/content/checkpoints/dqn_re_entrnenado_15k/agent_ctrl_best.pt')
agent.epsilon = 0.0  # sin exploración, pura explotación
print('Agente cargado')
# Out:
# Agente cargado

# %% [markdown]
# Prueba de funcionamiento del agente

# %%
cstr = CSTRSimulator(dt=1.0, control_limits=((300, 420), (90, 115)))
cstr.reset()

pid_controllers = [
    PIDController(kp=1.0, ki=0.1, kd=0.01, dt=1.0, output_limits=(300, 420)),
    PIDController(kp=1.0, ki=0.1, kd=0.01, dt=1.0, output_limits=(90, 115))
]
apply_action = ApplyAction(
    delta_percent_ctrl=0.3,
    pid_limits=[(0.01, 5.0), (0.001, 1.0), (0.0001, 1.0)],
    manipulable_ranges=[(300, 420), (90, 115)]
)

T_sp, V_sp = 340.0, 100.0
sps = [T_sp, V_sp]
pvs = [cstr.T_ss, cstr.V_ss]

# Acumular errores entre steps
error_integral = [0.0, 0.0]
error_prev     = [sps[i] - pvs[i] for i in range(2)]

traj_T, traj_V = [pvs[0]], [pvs[1]]
traj_kp0, traj_kp1 = [], []

detector = ResponseTimeDetector(proceso=cstr, env_type='simulation', dt=1.0, tolerance=0.02)
for step in range(20):
    errors = [sps[i] - pvs[i] for i in range(2)]

    # Acumular integral y derivada
    for i in range(2):
        error_integral[i] += errors[i] * 1.0
    error_derivative = [errors[i] - error_prev[i] for i in range(2)]
    error_prev = errors.copy()

    state = np.array([
        pvs[0], sps[0], errors[0], error_integral[0], error_derivative[0],
        pvs[1], sps[1], errors[1], error_integral[1], error_derivative[1],
    ], dtype=np.float32)

    action = agent.select_action(state, training=False)
    print(f'Step {step+1:2d} | action={action}', end='')

    pid_params = apply_action.translate(
        action=action, agent_type='ctrl', action_type='discrete',
        current_values=[(p.kp, p.ki, p.kd) for p in pid_controllers]
    )
    for i, (kp, ki, kd) in enumerate(pid_params):
        pid_controllers[i].kp = kp
        pid_controllers[i].ki = ki
        pid_controllers[i].kd = kd

    traj_kp0.append(pid_controllers[0].kp)
    traj_kp1.append(pid_controllers[1].kp)


    resultado = detector.estimate(pvs_inicial=pvs, sps=sps, pid_controllers=pid_controllers, max_time=15, reset_pid=False)

    pvs = resultado['pvs_final']
    traj_T.append(pvs[0])
    traj_V.append(pvs[1])
    print(f' | T={pvs[0]:.2f} | V={pvs[1]:.3f} | kp0={pid_controllers[0].kp:.4f} | kp1={pid_controllers[1].kp:.4f}')
# Out:
# Step  1 | action=[6 6] | T=332.61 | V=98.156 | kp0=1.0000 | kp1=1.0000
# Step  2 | action=[4 3] | T=329.05 | V=99.755 | kp0=1.0000 | kp1=0.7000
# Step  3 | action=[1 3] | T=356.92 | V=100.012 | kp0=1.0000 | kp1=0.4900
# Step  4 | action=[0 1] | T=346.69 | V=99.597 | kp0=1.3000 | kp1=0.4900
# Step  5 | action=[6 6] | T=346.02 | V=100.001 | kp0=1.3000 | kp1=0.4900
# Step  6 | action=[6 6] | T=342.17 | V=100.010 | kp0=1.3000 | kp1=0.4900
# Step  7 | action=[6 6] | T=342.17 | V=100.008 | kp0=1.3000 | kp1=0.4900
# Step  8 | action=[4 6] | T=339.62 | V=99.997 | kp0=1.3000 | kp1=0.4900
# Step  9 | action=[4 3] | T=339.62 | V=99.997 | kp0=1.3000 | kp1=0.3430
# Step 10 | action=[4 3] | T=339.62 | V=99.997 | kp0=1.3000 | kp1=0.2401
# Step 11 | action=[4 3] | T=339.62 | V=99.997 | kp0=1.3000 | kp1=0.1681
# Step 12 | action=[4 3] | T=339.62 | V=99.997 | kp0=1.3000 | kp1=0.1176
# Step 13 | action=[4 3] | T=339.62 | V=99.997 | kp0=1.3000 | kp1=0.0824
# Step 14 | action=[4 3] | T=339.62 | V=99.997 | kp0=1.3000 | kp1=0.0576
# Step 15 | action=[4 3] | T=339.62 | V=99.997 | kp0=1.3000 | kp1=0.0404
# Step 16 | action=[4 3] | T=339.62 | V=99.997 | kp0=1.3000 | kp1=0.0282
# Step 17 | action=[4 3] | T=339.62 | V=99.997 | kp0=1.3000 | kp1=0.0198
# Step 18 | action=[4 3] | T=339.62 | V=99.997 | kp0=1.3000 | kp1=0.0138
# Step 19 | action=[4 3] | T=339.62 | V=99.997 | kp0=1.3000 | kp1=0.0100
# Step 20 | action=[4 3] | T=339.62 | V=99.997 | kp0=1.3000 | kp1=0.0100

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(traj_T, marker='o', color='steelblue')
axes[0].axhline(T_sp, color='red', linestyle='--', label=f'SP={T_sp}')
axes[0].set_title('Temperatura T')
axes[0].set_xlabel('Step')
axes[0].set_ylabel('T (K)')
axes[0].legend()

axes[1].plot(traj_V, marker='o', color='orange')
axes[1].axhline(V_sp, color='red', linestyle='--', label=f'SP={V_sp}')
axes[1].set_title('Volumen V')
axes[1].set_xlabel('Step')
axes[1].set_ylabel('V (m³)')
axes[1].legend()

plt.suptitle('Evaluación agente DQN — T_sp=340K, V_sp=100m³', fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# El agente aprendio muy bien! llega rapido y sin overshots! Paso al entrenamiento del orch.

# %% [markdown]
# ## 8. Pruebas con otros SP
# Comparación del agente DQN CTRL pre-entrenado evaluado en una grilla de setpoints.

# %%
DEVICE             = 'cuda' if torch.cuda.is_available() else 'cpu'
MANIPULABLE_RANGES = [(300, 420), (90, 115)]
SEED               = 42
DQN_CHECKPOINT     = '/content/Control-PID-Adaptativo-Inteligente-mediante-Reinforcement-Learning/Version_4/Entrenamiento/CTRL/DQN/agent_ctrl_best_Test2.pt'

eval_config = {
    'env_config': {
        'architecture'           : 'simple',
        'env_type'               : 'simulation',
        'action_type'            : 'discrete',
        'n_manipulable_vars'     : 2,
        'manipulable_ranges'     : [(300, 420), (90, 115)],
        'manipulable_setpoints'  : None,
        'dt_usuario'             : 1.0,
        'max_steps'              : 100,
        'max_time_detector'      : 15,
        'reward_dead_band'       : 0.02,
        'delta_percent_ctrl'     : 0.3,
        'reward_weights'         : {'error': 3.0, 'tiempo': 0.1, 'overshoot': 0.1, 'energy': 0.05},
        'pid_limits'             : [(0.01, 5.0), (0.001, 1.0), (0.0001, 1.0)],
        'agent_controller_config': {'agent_type': 'discrete'},
        'env_type_config'        : {'dt': 1.0, 'control_limits': ((300, 420), (90, 115))},
        'stability_config'       : {
            'error_increase_tolerance': 1.2,
            'max_sign_changes_ratio'  : 0.2,
            'max_abrupt_change_ratio' : 0.03,
            'abrupt_change_threshold' : 0.3,
        },
    },
    'agent_ctrl_config': {
        'algorithm'         : 'dqn',
        'state_dim'         : 10,
        'action_dim'        : 7,
        'n_vars'            : 2,
        'action_type'       : 'discrete',
        'hidden_dims'       : (128, 64),
        'lr'                : 1e-05,
        'gamma'             : 0.99,
        'epsilon_start'     : 0.0,
        'epsilon_min'       : 0.0,
        'epsilon_decay'     : 0.9995,
        'batch_size'        : 128,
        'target_update_freq': 50,
        'buffer_type'       : 'priority',
        'buffer_size'       : 50000,
        'device'            : DEVICE,
        'seed'              : SEED,
    },
    'n_episodes'    : 1,
    'use_wandb'     : False,
    'checkpoint_dir': 'checkpoints/eval_tmp',
}

cstr = CSTRSimulator(dt=1.0, control_limits=(MANIPULABLE_RANGES[0], MANIPULABLE_RANGES[1]))
trainer = DQNTrainer(eval_config)
trainer.env.proceso.connect_external_process(cstr)
trainer.agent_ctrl.load(DQN_CHECKPOINT)
trainer.agent_ctrl.epsilon = 0.0   # sin exploración
print('Agente DQN cargado correctamente')
# Out:
# Agente DQN cargado correctamente

# %%
# ============ GRILLA DE SETPOINTS ============
T_setpoints = [320, 340, 360, 380, 400]   # K
V_setpoints = [100.0, 101.0, 102.0]       # m³

# ============ FUNCIÓN DE EVALUACIÓN ============
def evaluar_sp(trainer, T_sp, V_sp, max_steps=100):
    """Corre un episodio con setpoints fijos y devuelve las trayectorias."""
    state = trainer.env.reset()[0]
    trainer.env.manipulable_setpoints = [T_sp, V_sp]
    trainer.env._update_errors()
    state = trainer.env._get_observation()

    print(f'SP después del reset: {trainer.env.manipulable_setpoints}')

    T_hist, V_hist = [], []
    done = False
    step = 0

    while not done and step < max_steps:
        action = trainer.agent_ctrl.select_action(state, training=False)
        next_state, reward, terminated, truncated, info = trainer.env.step(action)
        done = terminated or truncated

        T_hist.append(trainer.env.manipulable_pvs[0])
        V_hist.append(trainer.env.manipulable_pvs[1])

        state = next_state
        step += 1

    return np.array(T_hist), np.array(V_hist)

# %%
# ============ EVALUAR Y GRAFICAR — VARIANDO T ============
fig, axes = plt.subplots(
    len(T_setpoints), 2,
    figsize=(14, 4 * len(T_setpoints))
)

for i, T_sp in enumerate(T_setpoints):
    V_sp = 101.0  # V fijo para comparar el efecto de T

    T_hist, V_hist = evaluar_sp(trainer, T_sp, V_sp)
    steps = np.arange(1, len(T_hist) + 1)

    # --- Temperatura ---
    ax_T = axes[i, 0]
    ax_T.plot(steps, T_hist, color='steelblue', linewidth=2, label='T (PV)')
    ax_T.axhline(T_sp, color='red', linestyle='--', linewidth=1.5, label=f'SP={T_sp}K')
    ax_T.set_title(f'Temperatura — SP={T_sp}K, V_sp={V_sp}m³')
    ax_T.set_xlabel('Step')
    ax_T.set_ylabel('T (K)')
    ax_T.legend()
    ax_T.grid(True, alpha=0.3)

    # --- Volumen ---
    ax_V = axes[i, 1]
    ax_V.plot(steps, V_hist, color='orange', linewidth=2, label='V (PV)')
    ax_V.axhline(V_sp, color='red', linestyle='--', linewidth=1.5, label=f'SP={V_sp}m³')
    ax_V.set_title(f'Volumen — SP={T_sp}K, V_sp={V_sp}m³')
    ax_V.set_xlabel('Step')
    ax_V.set_ylabel('V (m³)')
    ax_V.legend()
    ax_V.grid(True, alpha=0.3)

    T_final = T_hist[-1]
    V_final = V_hist[-1]
    print(f'T_sp={T_sp}K → T_final={T_final:.2f}K (error={abs(T_final-T_sp):.2f}K) | '
          f'V_final={V_final:.3f}m³ (error={abs(V_final-V_sp):.4f}m³)')

plt.suptitle('Evaluación DQN CTRL — Distintos Setpoints de T', fontsize=14, y=1.01)
plt.tight_layout()
plt.savefig('eval_dqn_ctrl_T_setpoints.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# SP después del reset: [320, 101.0]
# T_sp=320K → T_final=315.42K (error=4.58K) | V_final=90.000m³ (error=11.0000m³)
# SP después del reset: [340, 101.0]
# T_sp=340K → T_final=320.28K (error=19.72K) | V_final=96.799m³ (error=4.2006m³)
# SP después del reset: [360, 101.0]
# T_sp=360K → T_final=320.14K (error=39.86K) | V_final=96.075m³ (error=4.9249m³)
# SP después del reset: [380, 101.0]
# T_sp=380K → T_final=402.74K (error=22.74K) | V_final=99.121m³ (error=1.8792m³)
# SP después del reset: [400, 101.0]
# T_sp=400K → T_final=315.74K (error=84.26K) | V_final=102.195m³ (error=1.1948m³)

# %%
# ============ TAMBIÉN VARIAR V ============
fig, axes = plt.subplots(
    len(V_setpoints), 2,
    figsize=(14, 4 * len(V_setpoints))
)

T_sp_fijo = 340.0  # T fija para comparar el efecto de V

for i, V_sp in enumerate(V_setpoints):
    T_hist, V_hist = evaluar_sp(trainer, T_sp_fijo, V_sp)
    steps = np.arange(1, len(T_hist) + 1)

    ax_T = axes[i, 0]
    ax_T.plot(steps, T_hist, color='steelblue', linewidth=2)
    ax_T.axhline(T_sp_fijo, color='red', linestyle='--', linewidth=1.5, label=f'SP={T_sp_fijo}K')
    ax_T.set_title(f'Temperatura — T_sp={T_sp_fijo}K, V_sp={V_sp}m³')
    ax_T.set_xlabel('Step')
    ax_T.set_ylabel('T (K)')
    ax_T.legend()
    ax_T.grid(True, alpha=0.3)

    ax_V = axes[i, 1]
    ax_V.plot(steps, V_hist, color='orange', linewidth=2)
    ax_V.axhline(V_sp, color='red', linestyle='--', linewidth=1.5, label=f'SP={V_sp}m³')
    ax_V.set_title(f'Volumen — T_sp={T_sp_fijo}K, V_sp={V_sp}m³')
    ax_V.set_xlabel('Step')
    ax_V.set_ylabel('V (m³)')
    ax_V.legend()
    ax_V.grid(True, alpha=0.3)

    T_final = T_hist[-1]
    V_final = V_hist[-1]
    print(f'V_sp={V_sp}m³ → V_final={V_final:.3f}m³ (error={abs(V_final-V_sp):.4f}m³) | '
          f'T_final={T_final:.2f}K (error={abs(T_final-T_sp_fijo):.2f}K)')

plt.suptitle('Evaluación DQN CTRL — Distintos Setpoints de V', fontsize=14, y=1.01)
plt.tight_layout()
plt.savefig('eval_dqn_ctrl_V_setpoints.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# SP después del reset: [340.0, 100.0]
# V_sp=100.0m³ → V_final=100.738m³ (error=0.7383m³) | T_final=320.80K (error=19.20K)
# SP después del reset: [340.0, 101.0]
# V_sp=101.0m³ → V_final=100.153m³ (error=0.8473m³) | T_final=320.78K (error=19.22K)
# SP después del reset: [340.0, 102.0]
# V_sp=102.0m³ → V_final=102.000m³ (error=0.0000m³) | T_final=340.00K (error=0.00K)
