# %% [markdown]
# # W&B Sweep — DQN
# Búsqueda de hiperparámetros para el agente DQN en el ambiente Simple (CSTR).
# - Método: Random Search
# - Proyecto W&B: `Tesis_DQN_ORCH`
# - Arquitectura: Compleja (ORCH+CTRL)

# %% [markdown]
# ## 1. Instalación e Imports

# %%
import os
import random
import numpy as np
import torch
import wandb
import sys
import pandas as pd
import matplotlib.pyplot as plt
import types

# %%
# Clonar desde Github:
# !git clone https://github.com/valeriaeskenazi/Control-PID-Adaptativo-Inteligente-mediante-Reinforcement-Learning.git
PROJECT_PATH = '/content/Control-PID-Adaptativo-Inteligente-mediante-Reinforcement-Learning/Version_4'
sys.path.append(PROJECT_PATH)
# Out:
# Cloning into 'Control-PID-Adaptativo-Inteligente-mediante-Reinforcement-Learning'...
# remote: Enumerating objects: 1460, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 1460 (delta 8), reused 17 (delta 7), pack-reused 1440 (from 1)
# Receiving objects: 100% (1460/1460), 32.47 MiB | 19.73 MiB/s, done.
# Resolving deltas: 100% (872/872), done.

# %%
from Environment.Simulation_Env.Reactor_CSTR import CSTRSimulator
from Environment.PIDControlEnv_simple import PIDControlEnv_Simple
from Environment.PIDControlEnv_complex import PIDControlEnv_Complex
from Agente.DQN.train_DQN import DQNTrainer
from Agente.DQN.algorithm_DQN import DQNAgent
from Aux.Plots import SimplePlotter, print_summary

print('Imports completados')
print(f'PyTorch: {torch.__version__}')
print(f'Device: {"CUDA" if torch.cuda.is_available() else "CPU"}')
# Out:
# Imports completados
# PyTorch: 2.10.0+cpu
# Device: CPU

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %% [markdown]
# ## 2. Login W&B

# %%
# !pip install wandb --quiet

# %%
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ve326684 (ve326684-universidad-ort-uruguay) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ## 3. Configuración del Sweep

# %%
WANDB_ENTITY  = 've326684-universidad-ort-uruguay'
WANDB_PROJECT = 'Tesis_DQN_ORCH'
RUN_NAME      = 'orch_re-entrenando_test3_15k'
CTRL_CHECKPOINT = '/content/Control-PID-Adaptativo-Inteligente-mediante-Reinforcement-Learning/Version_4/Entrenamiento/CTRL/agent_ctrl_best_Test2.pt'

N_EPISODES               = 15000
EVAL_FREQUENCY           = 100
LOG_FREQUENCY            = 100
SAVE_FREQUENCY           = 2000
EARLY_STOPPING_PATIENCE  = 50
EARLY_STOPPING_MIN_DELTA_PCT = 0.01
SEED                     = 42
DEVICE                   = 'cuda' if torch.cuda.is_available() else 'cpu'

MANIPULABLE_RANGES = [(300, 420), (90, 115)]

trainer_config = {
    'env_config': {
        'architecture'        : 'jerarquica',
        'env_type'            : 'simulation',
        'n_manipulable_vars'  : 2,
        'manipulable_ranges'  : MANIPULABLE_RANGES,
        'n_target_vars'       : 1,
        'target_ranges'       : [(0.0, 1.0)],
        'target_setpoints'    : [0.4],
        'target_working_ranges': [(0.0, 2.0)],
        'dt_usuario'          : 1.0,
        'max_steps'           : 100,
        'max_time_detector'   : 60,
        'reward_dead_band'    : 0.02,
        'delta_percent_ctrl'  : 0.3,
        'delta_percent_orch'  : 0.03,
        'reward_weights'      : {'error': 1.0, 'tiempo': 0.3, 'overshoot': 0.2, 'energy': 0.1},
        'pid_limits'          : [(0.01, 5.0), (0.001, 1.0), (0.0001, 1.0)],
        'agent_orchestrator_config': {'agent_type': 'discrete'},
        'env_type_config'     : {'dt': 1.0, 'control_limits': (MANIPULABLE_RANGES[0], MANIPULABLE_RANGES[1])},
        'stability_config'    : {
            'error_increase_tolerance': 2.0,
            'max_sign_changes_ratio'  : 0.2,
            'max_abrupt_change_ratio' : 0.03,
            'abrupt_change_threshold' : 0.3,
        },
    },

    'ctrl_checkpoint_path': CTRL_CHECKPOINT,
    'agent_ctrl_config': {
        'state_dim'  : 10,
        'action_dim' : 7,
        'n_vars'     : 2,
        'action_type': 'discrete',
        'hidden_dims': (128, 64),
        'device'     : DEVICE,
    },

    'agent_orch_config': {
        'state_dim'         : 5,
        'action_dim'        : 3,
        'n_vars'            : 2,
        'hidden_dims'       : (128, 64),
        'lr'                : 1e-4,
        'gamma'             : 0.99,
        'epsilon_start'     : 1.0,
        'epsilon_min'       : 0.01,
        'epsilon_decay'     : 0.9995,
        'batch_size'        : 32,
        'target_update_freq': 50,
        'buffer_type'       : 'priority',
        'buffer_size'       : 10000,
        'device'            : DEVICE,
        'seed'              : SEED,
    },

    'n_episodes'                 : N_EPISODES,
    'eval_frequency'             : EVAL_FREQUENCY,
    'log_frequency'              : LOG_FREQUENCY,
    'save_frequency'             : SAVE_FREQUENCY,
    'checkpoint_dir'             : f'checkpoints/{RUN_NAME}',
    'early_stopping_patience'    : EARLY_STOPPING_PATIENCE,
    'early_stopping_min_delta_pct': EARLY_STOPPING_MIN_DELTA_PCT,
    'use_wandb': True,
}

# Reproducibilidad
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark     = False

# Init W&B
wandb.init(
    project = WANDB_PROJECT,
    entity  = WANDB_ENTITY,
    name    = RUN_NAME,
    tags    = ['post-fix', 'orch', '15k', 'produccion'],
    config  = trainer_config,
)

# Entrenar
cstr = CSTRSimulator(dt=1.0, control_limits=(MANIPULABLE_RANGES[0], MANIPULABLE_RANGES[1]))
trainer = DQNTrainer(trainer_config)
trainer.env.proceso.connect_external_process(cstr)
trainer.train()

# Guardar pesos en W&B
import os
checkpoint_path = f'checkpoints/{RUN_NAME}'
if os.path.exists(checkpoint_path):
    artifact = wandb.Artifact(
        name        = f'model_{RUN_NAME}',
        type        = 'model',
        description = 'Pesos ORCH post-fix, 15k episodios'
    )
    artifact.add_dir(checkpoint_path)
    wandb.log_artifact(artifact)
    print('✓ Pesos guardados en W&B')

# Métricas finales
wandb.log({
    'final_eval_reward'      : trainer.best_reward,
    'total_episodes'         : len(trainer.episode_rewards),
    'final_epsilon'          : trainer.epsilons[-1] if trainer.epsilons else 0,
    'final_reward_mean10'    : np.mean(trainer.episode_rewards[-10:]),
    'final_energy_mean10'    : np.mean(trainer.episode_energies[-10:]),
    'final_overshoot_mean10' : np.mean(trainer.episode_max_overshoots[-10:]),
})

run_name = wandb.run.name
wandb.finish()
print(f'Run completado: {run_name}')
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/wandb/run-20260308_021023-4nefxi6i</code>
# Syncing run <strong><a href='https://wandb.ai/ve326684-universidad-ort-uruguay/Tesis_DQN_ORCH/runs/4nefxi6i' target="_blank">orch_re-entrenando_test3_15k</a></strong> to <a href='https://wandb.ai/ve326684-universidad-ort-uruguay/Tesis_DQN_ORCH' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ve326684-universidad-ort-uruguay/Tesis_DQN_ORCH' target="_blank">https://wandb.ai/ve326684-universidad-ort-uruguay/Tesis_DQN_ORCH</a>
#  View run at <a href='https://wandb.ai/ve326684-universidad-ort-uruguay/Tesis_DQN_ORCH/runs/4nefxi6i' target="_blank">https://wandb.ai/ve326684-universidad-ort-uruguay/Tesis_DQN_ORCH/runs/4nefxi6i</a>
# Cargando agente CTRL pre-entrenado desde: /content/Control-PID-Adaptativo-Inteligente-mediante-Reinforcement-Learning/Version_4/Entrenamiento/CTRL/agent_ctrl_best_Test2.pt
#
# Episodio 0/15000
#   Reward: -2.08
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 42.2575
#   ORCH Epsilon: 0.9661
#
# Episodio 100/15000
#   Reward: -8.46
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 5.8167
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -4.40
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_ctrl_best.pt
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_orch_best.pt
# Checkpoint guardado: best
#
# Episodio 200/15000
#   Reward: -1.31
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 2.2837
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -1.22
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_ctrl_best.pt
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_orch_best.pt
# Checkpoint guardado: best
#
# Episodio 300/15000
#   Reward: -0.91
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 7.4030
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -7.31
#   Sin mejora: 1/50
#
# Episodio 400/15000
#   Reward: -5.32
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 2.3736
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -6.09
#   Sin mejora: 2/50
#
# Episodio 500/15000
#   Reward: -0.42
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 1.0595
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -1.12
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_ctrl_best.pt
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_orch_best.pt
# Checkpoint guardado: best
#
# Episodio 600/15000
#   Reward: -0.60
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 5.1139
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -1.06
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_ctrl_best.pt
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_orch_best.pt
# Checkpoint guardado: best
#
# Episodio 700/15000
#   Reward: -4.02
#   Length: 2
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 14.5522
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -1.15
#   Sin mejora: 1/50
#
# Episodio 800/15000
#   Reward: -17.79
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 10.7967
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -6.62
#   Sin mejora: 2/50
#
# Episodio 900/15000
#   Reward: -0.75
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 5.5215
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -18.31
#   Sin mejora: 3/50
#
# Episodio 1000/15000
#   Reward: -11.26
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 3.1371
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -18.68
#   Sin mejora: 4/50
#
# Episodio 1100/15000
#   Reward: -0.98
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 6.1567
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -3.78
#   Sin mejora: 5/50
#
# Episodio 1200/15000
#   Reward: -0.61
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 3.1817
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -5.16
#   Sin mejora: 6/50
#
# Episodio 1300/15000
#   Reward: -0.39
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 2.9172
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -1.22
#   Sin mejora: 7/50
#
# Episodio 1400/15000
#   Reward: -2.18
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 4.4965
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -10.30
#   Sin mejora: 8/50
#
# Episodio 1500/15000
#   Reward: -0.66
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 2.8654
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -1.28
#   Sin mejora: 9/50
#
# Episodio 1600/15000
#   Reward: -2.02
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 2.8431
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -1.04
#   Sin mejora: 10/50
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_ctrl_best.pt
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_orch_best.pt
# Checkpoint guardado: best
#
# Episodio 1700/15000
#   Reward: -0.28
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 1.6500
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -1.81
#   Sin mejora: 11/50
#
# Episodio 1800/15000
#   Reward: -0.54
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 4.8145
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -3.92
#   Sin mejora: 12/50
#
# Episodio 1900/15000
#   Reward: -26.99
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 3.1141
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -1.66
#   Sin mejora: 13/50
#
# Episodio 2000/15000
#   Reward: -3.04
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 3.7020
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -0.68
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_ctrl_best.pt
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_orch_best.pt
# Checkpoint guardado: best
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_ctrl_ep2000.pt
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_orch_ep2000.pt
# Checkpoint guardado: ep2000
#
# Episodio 2100/15000
#   Reward: -0.24
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 2.6814
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -11.14
#   Sin mejora: 1/50
#
# Episodio 2200/15000
#   Reward: -0.78
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 1.3129
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -6.87
#   Sin mejora: 2/50
#
# Episodio 2300/15000
#   Reward: -4.08
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 2.1538
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -1.81
#   Sin mejora: 3/50
#
# Episodio 2400/15000
#   Reward: -14.86
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 1.7238
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -5.06
#   Sin mejora: 4/50
#
# Episodio 2500/15000
#   Reward: -0.27
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 3.9389
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -18.70
#   Sin mejora: 5/50
#
# Episodio 2600/15000
#   Reward: -0.67
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 2.3843
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -2.60
#   Sin mejora: 6/50
#
# Episodio 2700/15000
#   Reward: -1.75
#   Length: 6
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 5.8085
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -0.75
#   Sin mejora: 7/50
#
# Episodio 2800/15000
#   Reward: -1.42
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 2.3092
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -10.54
#   Sin mejora: 8/50
#
# Episodio 2900/15000
#   Reward: -0.72
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 2.9709
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -9.85
#   Sin mejora: 9/50
#
# Episodio 3000/15000
#   Reward: -0.21
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 1.9386
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -5.63
#   Sin mejora: 10/50
#
# Episodio 3100/15000
#   Reward: -0.55
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 2.2374
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -0.69
#   Sin mejora: 11/50
#
# Episodio 3200/15000
#   Reward: -0.23
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 3.1178
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -0.55
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_ctrl_best.pt
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_orch_best.pt
# Checkpoint guardado: best
#
# Episodio 3300/15000
#   Reward: -0.37
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 2.1101
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -0.18
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_ctrl_best.pt
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_orch_best.pt
# Checkpoint guardado: best
#
# Episodio 3400/15000
#   Reward: -0.60
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 1.8964
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -1.08
#   Sin mejora: 1/50
#
# Episodio 3500/15000
#   Reward: -0.52
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 1.9040
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -0.22
#   Sin mejora: 2/50
#
# Episodio 3600/15000
#   Reward: -0.37
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 0.6424
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -1.78
#   Sin mejora: 3/50
#
# Episodio 3700/15000
#   Reward: -0.30
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 3.9401
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -4.77
#   Sin mejora: 4/50
#
# Episodio 3800/15000
#   Reward: -0.29
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 2.6532
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -0.70
#   Sin mejora: 5/50
#
# Episodio 3900/15000
#   Reward: -2.29
#   Length: 4
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 7.1638
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -0.54
#   Sin mejora: 6/50
#
# Episodio 4000/15000
#   Reward: -5.81
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 4.8612
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -2.68
#   Sin mejora: 7/50
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_ctrl_ep4000.pt
# Agente guardado en: checkpoints/orch_re-entrenando_test3_15k/agent_orch_ep4000.pt
# Checkpoint guardado: ep4000
#
# Episodio 4100/15000
#   Reward: -15.20
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 1.4447
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -0.56
#   Sin mejora: 8/50
#
# Episodio 4200/15000
#   Reward: -3.69
#   Length: 100
#   CTRL Loss: 0.0000
#   CTRL Epsilon: 0.0000
#   ORCH Loss: 3.5931
#   ORCH Epsilon: 0.0100
# Evaluación: Reward promedio = -1.56
#   Sin mejora: 9/50

# %%
runs = api.runs('ve326684-universidad-ort-uruguay/Tesis_DQN_ORCH')
for r in runs:
    if 'test3' in r.name.lower() or 'test3' in r.id.lower():
        print(r.name, '|', r.id, '|', r.state)
# Out:
# orch_re-entrenando_test3_15k | 4nefxi6i | crashed

# %%
api = wandb.Api()
run = api.run('ve326684-universidad-ort-uruguay/Tesis_DQN_ORCH/4nefxi6i')
for f in run.files():
    print(f.name)
# Out:
# requirements.txt
# wandb-metadata.json

# %%
artifact = api.artifact('ve326684-universidad-ort-uruguay/Tesis_DQN_ORCH/model_orch_re-entrenando_test3_15k:latest')
artifact.download(root='/content/checkpoints/orch_test3/')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/wandb/apis/normalize.py in wrapper(*args, **kwargs)
#      27         try:
# ---> 28             return func(*args, **kwargs)
#      29
#
# /usr/local/lib/python3.12/dist-packages/wandb/apis/public/api.py in _artifact(self, name, type, enable_tracking)
#    1557         path = FullArtifactPath(prefix=entity, project=project, name=artifact_name)
# -> 1558         artifact = Artifact._from_name(
#    1559             path=path,
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/artifacts/artifact.py in _from_name(cls, path, client, enable_tracking)
#     324         if server_supports(client, pb.PROJECT_ARTIFACT_COLLECTION_MEMBERSHIP):
# --> 325             return cls._membership_from_name(path=path, client=client)
#     326
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/artifacts/artifact.py in _membership_from_name(cls, path, client)
#     309             msg = f"artifact membership {path.name!r} not found in {entity_project!r}"
# --> 310             raise ValueError(msg)
#     311
#
# ValueError: artifact membership 'model_orch_re-entrenando_test3_15k:latest' not found in 've326684-universidad-ort-uruguay/Tesis_DQN_ORCH'
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# /tmp/ipykernel_538/1466252996.py in <cell line: 0>()
# ----> 1 artifact = api.artifact('ve326684-universidad-ort-uruguay/Tesis_DQN_ORCH/model_orch_re-entrenando_test3_15k:latest')
#       2 artifact.download(root='/content/checkpoints/orch_test3/')
#
# /usr/local/lib/python3.12/dist-packages/wandb/apis/normalize.py in wrapper(*args, **kwargs)
#      26         message = "Whoa, you found a bug."
#      27         try:
# ---> 28             return func(*args, **kwargs)
#      29
#      30         except requests.HTTPError as error:
#
# /usr/local/lib/python3.12/dist-packages/wandb/apis/public/api.py in artifact(self, name, type)
#    1614         This method is intended for external use only. Do not call `api.artifact()` within the wandb repository code.
#    1615         """
# -> 1616         return self._artifact(name=name, type=type, enable_tracking=True)
#    1617
#    1618     @normalize_exceptions
#
# /usr/local/lib/python3.12/dist-packages/wandb/apis/normalize.py in wrapper(*args, **kwargs)
#      80                 raise
#      81             else:
# ---> 82                 raise CommError(message, err).with_traceback(sys.exc_info()[2])
#      83
#      84     return wrapper
#
# /usr/local/lib/python3.12/dist-packages/wandb/apis/normalize.py in wrapper(*args, **kwargs)
#      26         message = "Whoa, you found a bug."
#      27         try:
# ---> 28             return func(*args, **kwargs)
#      29
#      30         except requests.HTTPError as error:
#
# /usr/local/lib/python3.12/dist-packages/wandb/apis/public/api.py in _artifact(self, name, type, enable_tracking)
#    1556
#    1557         path = FullArtifactPath(prefix=entity, project=project, name=artifact_name)
# -> 1558         artifact = Artifact._from_name(
#    1559             path=path,
#    1560             client=self.client,
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/artifacts/artifact.py in _from_name(cls, path, client, enable_tracking)
#     323
#     324         if server_supports(client, pb.PROJECT_ARTIFACT_COLLECTION_MEMBERSHIP):
# --> 325             return cls._membership_from_name(path=path, client=client)
#     326
#     327         gql_vars = {
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/artifacts/artifact.py in _membership_from_name(cls, path, client)
#     308             entity_project = f"{path.prefix}/{path.project}"
#     309             msg = f"artifact membership {path.name!r} not found in {entity_project!r}"
# --> 310             raise ValueError(msg)
#     311
#     312         return cls._from_membership(membership, target=path, client=client)
#
# CommError: artifact membership 'model_orch_re-entrenando_test3_15k:latest' not found in 've326684-universidad-ort-uruguay/Tesis_DQN_ORCH'

# %%
r = api.run('ve326684-universidad-ort-uruguay/Tesis_DQN_ORCH/4nefxi6i')
hist = list(r.scan_history())
df = pd.DataFrame(hist)

fig, axes = plt.subplots(2, 2, figsize=(14, 8))
metricas = ['reward', 'eval_reward', 'loss', 'epsilon']

for ax, col in zip(axes.flat, metricas):
    if col in df.columns:
        d = df[['_step', col]].dropna()
        ax.plot(d['_step'], d[col], alpha=0.3, color='steelblue')
        ax.plot(d['_step'], d[col].rolling(100, min_periods=1).mean(), color='red', lw=2)
        ax.set_title(col)
        ax.set_xlabel('Episodio')

plt.suptitle('ORCH test3 — hasta ep 4000', fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# La corrida crasheo, y consumio muchos recursos, y tampoco iba tan bien, vuelvo con otra.

# %% [markdown]
# ## Nueva corrida de 15000 episodios

# %% [markdown]
# Analisis de resultados

# %%
api = wandb.Api()
r = api.run('ve326684-universidad-ort-uruguay/Tesis_DQN_ORCH/wchc8qaf')
hist = list(r.scan_history())
print(len(hist), 'steps')
print(list(pd.DataFrame(hist).columns))
# Out:
# 5801 steps
# ['epsilon', 'energy', '_timestamp', '_step', 'loss', 'overshoot', '_runtime', 'reward', 'eval_reward', 'total_episodes', 'final_epsilon', 'final_energy_mean10', 'final_overshoot_mean10', 'final_reward_mean10', 'final_eval_reward']

# %%
df_orch = pd.DataFrame(hist)

fig, axes = plt.subplots(2, 2, figsize=(14, 8))
metricas = ['reward', 'eval_reward', 'loss', 'overshoot']

for ax, col in zip(axes.flat, metricas):
    d = df_orch[['_step', col]].dropna()
    ax.plot(d['_step'], d[col], alpha=0.3, color='steelblue')
    ax.plot(d['_step'], d[col].rolling(200, min_periods=1).mean(), color='red', lw=2)
    ax.set_title(col)
    ax.set_xlabel('Episodio')

plt.suptitle('ORCH 15k — ¿aprendió?', fontweight='bold')
plt.tight_layout()
plt.show()

# %%
from Agente.DQN.algorithm_DQN import DQNAgent

# %%
# ── Cargar CTRL ────────────────────────────────────────────────────────────────
agent_ctrl = DQNAgent(state_dim=10, action_dim=7, n_vars=2, agent_role='ctrl',
                      hidden_dims=(128, 64), device='cpu', seed=42)
agent_ctrl.load('/content/checkpoints/orch_re-entrenando_15k/agent_ctrl_best.pt')
agent_ctrl.epsilon = 0.0

# ── Cargar ORCH ────────────────────────────────────────────────────────────────
agent_orch = DQNAgent(state_dim=5, action_dim=3, n_vars=2, agent_role='orch',
                      hidden_dims=(128, 64), device='cpu', seed=42)
agent_orch.load('/content/checkpoints/orch_re-entrenando_15k/agent_orch_best.pt')
agent_orch.epsilon = 0.0

print('Ambos agentes cargados')
# Out:
# Ambos agentes cargados

# %%
import matplotlib.pyplot as plt
import types
import numpy as np

def _run_episode_verbose(self, episode, training=False):
    obs = self.env.reset()[0]
    state_ctrl = obs['ctrl']
    state_orch = obs['orch']

    cstr = self.env.proceso.external_process

    cb_traj = [cstr.state[1]]
    T_traj  = [cstr.state[3]]
    V_traj  = [cstr.state[4]]

    done = False
    step = 0
    episode_reward = 0

    while not done and step < self.max_steps_per_episode:
        action_orch = self.agent_orch.select_action(state_orch, training=False)
        action_ctrl = self.agent_ctrl.select_action(state_ctrl, training=False)
        action = {'ctrl': action_ctrl, 'orch': action_orch}

        next_obs, reward, terminated, truncated, info = self.env.step(action)
        done = terminated or truncated

        cb_traj.append(cstr.state[1])
        T_traj.append(cstr.state[3])
        V_traj.append(cstr.state[4])

        state_ctrl = next_obs['ctrl']
        state_orch = next_obs['orch']
        episode_reward += reward
        step += 1

    # Graficar
    fig, axes = plt.subplots(1, 3, figsize=(15, 4))
    steps = range(len(cb_traj))

    axes[0].plot(steps, cb_traj, color='green')
    axes[0].axhline(0.4, color='red', linestyle='--', label='Objetivo=0.4')
    axes[0].set_title('Cb (mol/m³)')
    axes[0].set_xlabel('Step')
    axes[0].legend()

    axes[1].plot(steps, T_traj, color='steelblue')
    axes[1].set_title('T (K)')
    axes[1].set_xlabel('Step')

    axes[2].plot(steps, V_traj, color='orange')
    axes[2].axhline(102, color='red', linestyle='--', label='V_ss=102')
    axes[2].set_title('V (m³)')
    axes[2].set_xlabel('Step')
    axes[2].legend()

    plt.suptitle(f'Evaluación ORCH+CTRL | Cb final={cb_traj[-1]:.4f} | Reward={episode_reward/step:.3f}',
                 fontweight='bold')
    plt.tight_layout()
    plt.show()

    print(f'Cb final: {cb_traj[-1]:.4f} | Error: {abs(cb_traj[-1]-0.4):.4f} | Reward: {episode_reward/step:.4f}')

# %%
trainer_eval = DQNTrainer(trainer_config)
trainer_eval.env.proceso.connect_external_process(
    CSTRSimulator(dt=1.0, control_limits=((300, 420), (90, 115)))
)
trainer_eval.agent_ctrl.load('/content/checkpoints/orch_re-entrenando_15k/agent_ctrl_best.pt')
trainer_eval.agent_ctrl.epsilon = 0.0
trainer_eval.agent_orch.load('/content/checkpoints/orch_re-entrenando_15k/agent_orch_best.pt')
trainer_eval.agent_orch.epsilon = 0.0

# Evaluar y ver trayectorias
trainer_eval._run_episode_verbose = types.MethodType(_run_episode_verbose, trainer_eval)
trainer_eval._run_episode_verbose(episode=0, training=False)
# Out:
# Cargando agente CTRL pre-entrenado desde: /content/Control-PID-Adaptativo-Inteligente-mediante-Reinforcement-Learning/Version_4/Entrenamiento/CTRL/agent_ctrl_best_Test2.pt
# Cb final: 0.2547 | Error: 0.1453 | Reward: -0.6441

# %%
trainer_eval = DQNTrainer(trainer_config)
trainer_eval.env.proceso.connect_external_process(
    CSTRSimulator(dt=1.0, control_limits=((300, 420), (90, 115)))
)
trainer_eval.agent_ctrl.load('/content/checkpoints/orch_re-entrenando_15k/agent_ctrl_best.pt')
trainer_eval.agent_ctrl.epsilon = 0.0
trainer_eval.agent_orch.load('/content/checkpoints/orch_re-entrenando_15k/agent_orch_best.pt')
trainer_eval.agent_orch.epsilon = 0.0

# Evaluar y ver trayectorias
trainer_eval._run_episode_verbose = types.MethodType(_run_episode_verbose, trainer_eval)
trainer_eval._run_episode_verbose(episode=0, training=False)
# Out:
# Cargando agente CTRL pre-entrenado desde: /content/Control-PID-Adaptativo-Inteligente-mediante-Reinforcement-Learning/Version_4/Entrenamiento/CTRL/agent_ctrl_best_Test2.pt
# Cb final: 0.0112 | Error: 0.3888 | Reward: -0.1664

# %%
trainer_eval = DQNTrainer(trainer_config)
trainer_eval.env.proceso.connect_external_process(
    CSTRSimulator(dt=1.0, control_limits=((300, 420), (90, 115)))
)
trainer_eval.agent_ctrl.load('/content/checkpoints/orch_re-entrenando_15k/agent_ctrl_best.pt')
trainer_eval.agent_ctrl.epsilon = 0.0
trainer_eval.agent_orch.load('/content/checkpoints/orch_re-entrenando_15k/agent_orch_best.pt')
trainer_eval.agent_orch.epsilon = 0.0

# Evaluar y ver trayectorias
trainer_eval._run_episode_verbose = types.MethodType(_run_episode_verbose, trainer_eval)
trainer_eval._run_episode_verbose(episode=0, training=False)
# Out:
# Cargando agente CTRL pre-entrenado desde: /content/Control-PID-Adaptativo-Inteligente-mediante-Reinforcement-Learning/Version_4/Entrenamiento/CTRL/agent_ctrl_best_Test2.pt
# Cb final: 0.2730 | Error: 0.1270 | Reward: -1.1259

# %%
cstr = trainer_eval.env.proceso.external_process
for i in range(3):
    trainer_eval.env.reset()
    print(f'Reset {i+1}: Cb={cstr.state[1]:.4f}, T={cstr.state[3]:.2f}, V={cstr.state[4]:.2f}')
# Out:
# Reset 1: Cb=0.4354, T=340.00, V=102.00
# Reset 2: Cb=0.4354, T=340.00, V=102.00
# Reset 3: Cb=0.4354, T=340.00, V=102.00

# %%
trainer_eval.env.reset()
for i, pid in enumerate(trainer_eval.env.pid_controllers):
    print(f'PID var{i}: kp={pid.kp:.4f}, ki={pid.ki:.6f}, kd={pid.kd:.6f}')
print('SPs iniciales:', trainer_eval.env.current_SPs_manipulable)
# Out:
# PID var0: kp=0.0100, ki=1.000000, kd=0.000100
# PID var1: kp=0.0100, ki=0.199927, kd=0.005275
# SPs iniciales: [344.927258364143, 103.31998982884657]

# %%
def _run_episode_verbose(self, episode, training=False):
    obs, info = self.env.reset()

    # Forzar condiciones iniciales correctas
    cstr = self.env.proceso.external_process
    self.env.current_SPs_manipulable = [cstr.T_ss, cstr.V_ss]  # [340, 102]
    self.env.target_pvs = [cstr.state[1]]                       # Cb real
    self.env.target_setpoints = [0.4]
    self.env.new_SP = [cstr.T_ss, cstr.V_ss]

    # Resetear errores
    self.env.error_integral_target = [0.0]
    self.env.error_prevs_target = [0.0]
    self.env.error_target = [0.0]

    # Recalcular observación con los valores corregidos
    obs = self.env._get_observation()

    state_ctrl = obs['ctrl']
    state_orch = obs['orch']

    cb_traj = [cstr.state[1]]
    T_traj  = [cstr.state[3]]
    V_traj  = [cstr.state[4]]

    done = False
    step = 0
    episode_reward = 0

    while not done and step < self.max_steps_per_episode:
        action_orch = self.agent_orch.select_action(state_orch, training=False)
        action_ctrl = self.agent_ctrl.select_action(state_ctrl, training=False)
        action = {'ctrl': action_ctrl, 'orch': action_orch}

        next_obs, reward, terminated, truncated, info = self.env.step(action)
        done = terminated or truncated

        cb_traj.append(cstr.state[1])
        T_traj.append(cstr.state[3])
        V_traj.append(cstr.state[4])

        state_ctrl = next_obs['ctrl']
        state_orch = next_obs['orch']
        episode_reward += reward
        step += 1

    # Graficar
    fig, axes = plt.subplots(1, 3, figsize=(15, 4))
    steps = range(len(cb_traj))

    axes[0].plot(steps, cb_traj, color='green')
    axes[0].axhline(0.4, color='red', linestyle='--', label='Objetivo=0.4')
    axes[0].set_title('Cb (mol/m³)'); axes[0].set_xlabel('Step'); axes[0].legend()

    axes[1].plot(steps, T_traj, color='steelblue')
    axes[1].set_title('T (K)'); axes[1].set_xlabel('Step')

    axes[2].plot(steps, V_traj, color='orange')
    axes[2].axhline(102, color='red', linestyle='--', label='V_ss=102')
    axes[2].set_title('V (m³)'); axes[2].set_xlabel('Step'); axes[2].legend()

    plt.suptitle(f'Cb final={cb_traj[-1]:.4f} | Error={abs(cb_traj[-1]-0.4):.4f} | Reward={episode_reward/step:.3f}',
                 fontweight='bold')
    plt.tight_layout()
    plt.show()

    print(f'Cb final: {cb_traj[-1]:.4f} | Error: {abs(cb_traj[-1]-0.4):.4f}')

trainer_eval._run_episode_verbose = types.MethodType(_run_episode_verbose, trainer_eval)
trainer_eval._run_episode_verbose(episode=0, training=False)
# Out:
# Cb final: 0.4477 | Error: 0.0477

# %%
for i in range(5):
    trainer_eval._run_episode_verbose(episode=i, training=False)
# Out:
# Cb final: 0.0133 | Error: 0.3867
# Cb final: 0.0954 | Error: 0.3046
# Cb final: 0.8648 | Error: 0.4648
# Cb final: 0.7663 | Error: 0.3663
# Cb final: 0.0228 | Error: 0.3772

# %%
# Cambiar parámetros del ambiente sin reentrenar
trainer_eval.env.max_time_detector = 30        # antes era 15
trainer_eval.env.apply_action_orch.delta_percent_orch = 0.05  # antes era 0.1

trainer_eval._run_episode_verbose(episode=0, training=False)
# Out:
# Cb final: 0.5602 | Error: 0.1602

# %%
# Cambiar parámetros del ambiente sin reentrenar
trainer_eval.env.max_time_detector = 30        # antes era 15
trainer_eval.env.apply_action_orch.delta_percent_orch = 0.1  # antes era 0.1

trainer_eval._run_episode_verbose(episode=0, training=False)
# Out:
# Cb final: 0.0177 | Error: 0.3823

# %%
# Cambiar parámetros del ambiente sin reentrenar
trainer_eval.env.max_time_detector = 15        # antes era 15
trainer_eval.env.apply_action_orch.delta_percent_orch = 0.05  # antes era 0.1

trainer_eval._run_episode_verbose(episode=0, training=False)
# Out:
# Cb final: 0.0056 | Error: 0.3944

# %% [markdown]
# Dadas las dificultadas que se dieron para corriborar el desempeño del agente, y visto que aumentando el tiempo de deteccion y reducinedo el delta mejor, hago una nueva notebook para eso
